# %%
import pandas as pd

# %%
hh102 = pd.read_csv("./hh102.ann.txt", sep='\t', names=['timestamp','sensor','Translate01','Translate02','Message','SensorType','annotation' ] )

# %%
hh102
# Out:
#                         timestamp sensor Translate01 Translate02 Message  \
# 0      2011-06-15 00:06:32.834414   M021     Bedroom         Bed      ON
# 1      2011-06-15 00:06:33.988964   M021     Bedroom         Bed     OFF
# 2      2011-06-15 00:15:01.957718  LS013      Ignore      Ignore       6
# 3      2011-06-15 00:25:01.892474  LS013      Ignore      Ignore       7
# 4      2011-06-15 03:37:46.585185   M021     Bedroom         Bed      ON
# ...                           ...    ...         ...         ...     ...
# 407505 2011-08-15 22:44:24.343584  LS020      Ignore      Ignore      23
# 407506 2011-08-15 22:54:24.303897  LS020      Ignore      Ignore      22
# 407507 2011-08-15 22:54:25.727398  LS021      Ignore      Ignore      17
# 407508 2011-08-15 23:04:25.687194  LS021      Ignore      Ignore      18
# 407509 2011-08-15 23:24:24.044725  LS020      Ignore      Ignore      23
#
#                   SensorType      annotation
# 0            Control4-Motion           Sleep
# ...

# %%
hh102["timestamp"] = pd.to_datetime(hh102['timestamp'], format='%d/%m/%Y %H:%M:%S')

# %%
hh102.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407510 entries, 0 to 407509
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   timestamp    407510 non-null  datetime64[ns]
#  1   sensor       407510 non-null  object
#  2   Translate01  407510 non-null  object
#  3   Translate02  407510 non-null  object
#  4   Message      407510 non-null  object
#  5   SensorType   407510 non-null  object
#  6   annotation   407510 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 21.8+ MB

# %%
hh102["daycase"] = hh102["timestamp"].apply(lambda x: str(x.year) + "-" + str(x.month) + "-" + str(x.day))

# %%
hh102
# Out:
#                         timestamp sensor Translate01 Translate02 Message  \
# 0      2011-06-15 00:06:32.834414   M021     Bedroom         Bed      ON
# 1      2011-06-15 00:06:33.988964   M021     Bedroom         Bed     OFF
# 2      2011-06-15 00:15:01.957718  LS013      Ignore      Ignore       6
# 3      2011-06-15 00:25:01.892474  LS013      Ignore      Ignore       7
# 4      2011-06-15 03:37:46.585185   M021     Bedroom         Bed      ON
# ...                           ...    ...         ...         ...     ...
# 407505 2011-08-15 22:44:24.343584  LS020      Ignore      Ignore      23
# 407506 2011-08-15 22:54:24.303897  LS020      Ignore      Ignore      22
# 407507 2011-08-15 22:54:25.727398  LS021      Ignore      Ignore      17
# 407508 2011-08-15 23:04:25.687194  LS021      Ignore      Ignore      18
# 407509 2011-08-15 23:24:24.044725  LS020      Ignore      Ignore      23
#
#                   SensorType      annotation    daycase
# ...

# %%
hh102_0701 = hh102[hh102["daycase"]=="2011-7-1"]

# %%
hh102_0701
# Out:
#                         timestamp sensor Translate01   Translate02 Message  \
# 116576 2011-07-01 00:05:40.811591   T104      Ignore  BathroomTemp      24
# 116577 2011-07-01 00:18:19.873791   T103      Ignore  BathroomTemp      25
# 116578 2011-07-01 03:40:01.562379   M021     Bedroom           Bed      ON
# 116579 2011-07-01 03:40:02.671886   M021     Bedroom           Bed     OFF
# 116580 2011-07-01 05:25:29.775043  LS004      Ignore        Ignore       1
# ...                           ...    ...         ...           ...     ...
# 123057 2011-07-01 23:34:03.615572   T104      Ignore  BathroomTemp      24
# 123058 2011-07-01 23:34:06.003339  LS019      Ignore        Ignore      17
# 123059 2011-07-01 23:34:39.222528  LS022      Ignore        Ignore       9
# 123060 2011-07-01 23:35:09.399569  LS020      Ignore        Ignore      24
# 123061 2011-07-01 23:46:00.269234  LS021      Ignore        Ignore      18
#
#                   SensorType annotation   daycase
# ...

# %%
hh102_0701["timestamp"] = pd.to_datetime(hh102_0701["timestamp"], format='%Y-%m-%d %H:%M:%S')
# Out:
# <ipython-input-44-1ff1706ce2c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hh102_0701["timestamp"] = pd.to_datetime(hh102_0701["timestamp"], format='%Y-%m-%d %H:%M:%S')

# %%
hh102_0701['timestamp'] = hh102_0701['timestamp'].apply(lambda x: x.replace(microsecond=0))
# Out:
# <ipython-input-45-55f52f3679da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hh102_0701['timestamp'] = hh102_0701['timestamp'].apply(lambda x: x.replace(microsecond=0))

# %%
hh102_0701
# Out:
#                  timestamp sensor Translate01   Translate02 Message  \
# 116576 2011-07-01 00:05:40   T104      Ignore  BathroomTemp      24
# 116577 2011-07-01 00:18:19   T103      Ignore  BathroomTemp      25
# 116578 2011-07-01 03:40:01   M021     Bedroom           Bed      ON
# 116579 2011-07-01 03:40:02   M021     Bedroom           Bed     OFF
# 116580 2011-07-01 05:25:29  LS004      Ignore        Ignore       1
# ...                    ...    ...         ...           ...     ...
# 123057 2011-07-01 23:34:03   T104      Ignore  BathroomTemp      24
# 123058 2011-07-01 23:34:06  LS019      Ignore        Ignore      17
# 123059 2011-07-01 23:34:39  LS022      Ignore        Ignore       9
# 123060 2011-07-01 23:35:09  LS020      Ignore        Ignore      24
# 123061 2011-07-01 23:46:00  LS021      Ignore        Ignore      18
#
#                   SensorType annotation   daycase
# 116576  Control4-Temperature      Sleep  2011-7-1
# ...

# %%
hh102_0701["timestamp"]= hh102_0701['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# <ipython-input-48-cdc71ecea245>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hh102_0701["timestamp"]= hh102_0701['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
hh102_0701.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6486 entries, 116576 to 123061
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    6486 non-null   object
#  1   sensor       6486 non-null   object
#  2   Translate01  6486 non-null   object
#  3   Translate02  6486 non-null   object
#  4   Message      6486 non-null   object
#  5   SensorType   6486 non-null   object
#  6   annotation   6486 non-null   object
#  7   daycase      6486 non-null   object
# dtypes: object(8)
# memory usage: 456.0+ KB

# %%
hh102_0701
# Out:
#                   timestamp sensor Translate01   Translate02 Message  \
# 116576  2011-07-01 00:05:40   T104      Ignore  BathroomTemp      24
# 116577  2011-07-01 00:18:19   T103      Ignore  BathroomTemp      25
# 116578  2011-07-01 03:40:01   M021     Bedroom           Bed      ON
# 116579  2011-07-01 03:40:02   M021     Bedroom           Bed     OFF
# 116580  2011-07-01 05:25:29  LS004      Ignore        Ignore       1
# ...                     ...    ...         ...           ...     ...
# 123057  2011-07-01 23:34:03   T104      Ignore  BathroomTemp      24
# 123058  2011-07-01 23:34:06  LS019      Ignore        Ignore      17
# 123059  2011-07-01 23:34:39  LS022      Ignore        Ignore       9
# 123060  2011-07-01 23:35:09  LS020      Ignore        Ignore      24
# 123061  2011-07-01 23:46:00  LS021      Ignore        Ignore      18
#
#                   SensorType annotation   daycase
# 116576  Control4-Temperature      Sleep  2011-7-1
# ...

# %%
import csv

# %%
hh102_0701.drop(columns = "daycase",axis = 1).to_csv("./hh102_0701.txt", sep='\t', index=False, header=False)
